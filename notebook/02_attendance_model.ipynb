# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score

from xgboost import XGBClassifier

import joblib, json, os

# %%
df = pd.read_csv("../data/processed_attendance.csv")
df
# Out:
#    student_id        date subject  present dept  semester  total_classes  \
# 0         102  2024-01-10    Math        0  CSE         4             10
# 1         101  2024-01-10    Math        1  CSE         4             10
# 2         103  2024-01-10    Math        1  CSE         4             10
#
#    total_present  overall_att     last7  last30  streak  week     trend  label
# 0              3          0.3  0.285714     0.3       1     2  0.047619      1
# 1              8          0.8  0.857143     0.8       0     2  0.285714      0
# 2              9          0.9  0.857143     0.9       0     2 -0.333333      0

# %%
feature_cols = ["overall_att", "last7", "last30", "streak", "trend"]

X = df[feature_cols].fillna(0)
y = df["label"]

X.head(), y.value_counts()
# Out:
# (   overall_att     last7  last30  streak     trend
#  0          0.3  0.285714     0.3       1  0.047619
#  1          0.8  0.857143     0.8       0  0.285714
#  2          0.9  0.857143     0.9       0 -0.333333,
#  label
#  0    2
#  1    1
#  Name: count, dtype: int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,      # 30% test (change if you want)
    stratify=y,         # class ratio same rahe
    random_state=42
)

X_train.shape, X_test.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(
#       2     X,
#       3     y,
#       4     test_size=0.3,      # 30% test (change if you want)
#       5     stratify=y,         # class ratio same rahe
#       6     random_state=42
#       7 )
#       9 X_train.shape, X_test.shape
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\sklearn\model_selection\_split.py:2940, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2936         CVClass = ShuffleSplit
#    2938     cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
# -> 2940     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2942 train, test = ensure_common_namespace_device(arrays[0], train, test)
#    2944 return list(
#    2945     chain.from_iterable(
#    2946         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2947     )
#    2948 )
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\sklearn\model_selection\_split.py:1927, in BaseShuffleSplit.split(self, X, y, groups)
#    1897 """Generate indices to split data into training and test set.
#    1898
#    1899 Parameters
#    (...)   1924 to an integer.
#    1925 """
#    1926 X, y, groups = indexable(X, y, groups)
# -> 1927 for train, test in self._iter_indices(X, y, groups):
#    1928     yield train, test
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\sklearn\model_selection\_split.py:2342, in StratifiedShuffleSplit._iter_indices(self, X, y, groups)
#    2340 class_counts = np.bincount(y_indices)
#    2341 if np.min(class_counts) < 2:
# -> 2342     raise ValueError(
#    2343         "The least populated class in y has only 1"
#    2344         " member, which is too few. The minimum"
#    2345         " number of groups for any class cannot"
#    2346         " be less than 2."
#    2347     )
#    2349 if n_train < n_classes:
#    2350     raise ValueError(
#    2351         "The train_size = %d should be greater or "
#    2352         "equal to the number of classes = %d" % (n_train, n_classes)
#    2353     )
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.33,      # ~1 student test, 2 train
    random_state=42      # reproducible
    # stratify=y   # <-- isko hata diya
)

X_train.shape, X_test.shape, y_train, y_test
# Out:
# ((2, 5),
#  (1, 5),
#  1    0
#  2    0
#  Name: label, dtype: int64,
#  0    1
#  Name: label, dtype: int64)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
num_neg = (y_train == 0).sum()
num_pos = (y_train == 1).sum()

print("Safe (0):", num_neg)
print("Risk (1):", num_pos)

scale_pos_weight = num_neg / num_pos if num_pos > 0 else 1.0
scale_pos_weight
# Out:
# Safe (0): 2
# Risk (1): 0
# 1.0

# %%
xgb_model = XGBClassifier(
    n_estimators=200,
    max_depth=4,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="binary:logistic",
    eval_metric="logloss",
    scale_pos_weight=scale_pos_weight,
    n_jobs=-1,
    random_state=42
)

xgb_model.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[8], line 14
#       1 xgb_model = XGBClassifier(
#       2     n_estimators=200,
#       3     max_depth=4,
#    (...)     11     random_state=42
#      12 )
# ---> 14 xgb_model.fit(X_train_scaled, y_train)
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\xgboost\sklearn.py:1806, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1786 evals_result: EvalsLog = {}
#    1787 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1788     missing=self.missing,
#    1789     X=X,
#    (...)   1803     feature_types=feature_types,
#    1804 )
# -> 1806 self._Booster = train(
#    1807     params,
#    1808     train_dmatrix,
#    1809     self.get_num_boosting_rounds(),
#    1810     evals=evals,
#    1811     early_stopping_rounds=self.early_stopping_rounds,
#    1812     evals_result=evals_result,
#    1813     obj=obj,
#    1814     custom_metric=metric,
#    1815     verbose_eval=verbose,
#    1816     xgb_model=model,
#    1817     callbacks=self.callbacks,
#    1818 )
#    1820 if not callable(self.objective):
#    1821     self.objective = params["objective"]
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\xgboost\training.py:199, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     197 if cb_container.before_iteration(bst, i, dtrain, evals):
#     198     break
# --> 199 bst.update(dtrain, iteration=i, fobj=obj)
#     200 if cb_container.after_iteration(bst, i, dtrain, evals):
#     201     break
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\xgboost\core.py:2433, in Booster.update(self, dtrain, iteration, fobj)
#    2430 self._assign_dmatrix_features(dtrain)
#    2432 if fobj is None:
# -> 2433     _check_call(
#    2434         _LIB.XGBoosterUpdateOneIter(
#    2435             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2436         )
#    2437     )
#    2438 else:
#    2439     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\xgboost\core.py:323, in _check_call(ret)
#     312 """Check the return value of C API call
#     313
#     314 This function will raise exception when error occurs.
#    (...)    320     return value from API calls
#     321 """
#     322 if ret != 0:
# --> 323     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: [02:11:10] C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:119: Check failed: is_valid: base_score must be in (0,1) for the logistic loss.

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression()

log_model.fit(X_train_scaled, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       1 from sklearn.linear_model import LogisticRegression
#       3 log_model = LogisticRegression()
# ----> 5 log_model.fit(X_train_scaled, y_train)
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\Desktop\campus_companion\attendance_ml\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1335, in LogisticRegression.fit(self, X, y, sample_weight)
#    1333 classes_ = self.classes_
#    1334 if n_classes < 2:
# -> 1335     raise ValueError(
#    1336         "This solver needs samples of at least 2 classes"
#    1337         " in the data, but the data contains only one"
#    1338         " class: %r" % classes_[0]
#    1339     )
#    1341 if len(self.classes_) == 2:
#    1342     n_classes = 1
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: np.int64(0)

# %%
# For tiny dummy data, use full dataset for training
X_train = X.copy()
y_train = y.copy()

# We'll still keep X_test, y_test same as train (just for demo)
X_test = X.copy()
y_test = y.copy()

X_train.shape, X_test.shape, y_train.value_counts()
# Out:
# ((3, 5),
#  (3, 5),
#  label
#  0    2
#  1    1
#  Name: count, dtype: int64)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression()
log_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = log_model.predict(X_test_scaled)

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Confusion Matrix:
# [[2 0]
#  [0 1]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000         2
#            1      1.000     1.000     1.000         1
#
#     accuracy                          1.000         3
#    macro avg      1.000     1.000     1.000         3
# weighted avg      1.000     1.000     1.000         3

# %%
import os, joblib, json

MODEL_DIR = "../model_artifacts"
os.makedirs(MODEL_DIR, exist_ok=True)

joblib.dump(log_model, os.path.join(MODEL_DIR, "attendance_log_model.pkl"))
joblib.dump(scaler, os.path.join(MODEL_DIR, "scaler.pkl"))

with open(os.path.join(MODEL_DIR, "feature_cols.json"), "w") as f:
    json.dump(feature_cols, f)

print("Saved:", os.listdir(MODEL_DIR))
# Out:
# Saved: ['attendance_log_model.pkl', 'feature_cols.json', 'scaler.pkl']

# %%
model_artifacts ready
# Out:
#   Cell In[15], line 1
#     model_artifacts ready
#                     ^
# SyntaxError: invalid syntax
